# %%
import pandas as pd

# %%
assignment_grade_file_path = "hello-c-grades-Test-IIST20SEP.csv"
#file2_path = "file2.csv"

# Load the CSV files into pandas DataFrames
df1 = pd.read_csv(assignment_grade_file_path)
df1
# Out:
#   assignment_name                                     assignment_url  \
# 0         Hello C  https://classroom.github.com/classrooms/143834...
# 1         Hello C  https://classroom.github.com/classrooms/143834...
# 2         Hello C  https://classroom.github.com/classrooms/143834...
#
#                                     starter_code_url  \
# 0  https://api.github.com/repos/education/autogra...
# 1  https://api.github.com/repos/education/autogra...
# 2  https://api.github.com/repos/education/autogra...
#
#              github_username roster_identifier  \
# 0  0818cs211032-AnshulSharma               NaN
# 1        CS211066-HarshHatej       Harsh Hatej
# 2                      ghost  Abhishek Rajpoot
#
#              student_repository_name  \
# 0  hello-c-0818cs211032-AnshulSharma
# 1        hello-c-CS211066-HarshHatej
# 2    hello-c-CS211009-AbhishekRajput
#
#                               student_repository_url     submission_timestamp  \
# ...
